# %% [markdown]
# # Notebook Objective:
# This is final notebook for DOCVQA dataset preparation. This notebook contains all type of preprocessed dataset for train, valid and test.
# Contents:
# - Basic processing, creating full image path, create dataframe from json file [On training, validation and test]
# - Read image in Pillow --> save the form --> Removing full image path [On training, validation and test]
# - Converting Pandas Dataframe to Huggingface dataset [On training, validation and test]
# - Adding ground truth column which contains ground truth parsing information i.e. gt_parses [On training and Validation]
# - Sample data checking whether everything processed correctly or not
# - Huggingface dataset dictionary creation to store all the training, validation and test dataset in a single container
# - Save the whole processed dataset in disk
# - This notebook experimented on 20000 train, 500 valid and 200 test data
# - Lastly I have pushed the dataset both with and without gtparse content so that we can use different dataset as per different model's requirement

# %% [markdown]
# ## Importing Necessary Dependencies

# %%
# !pip install -q datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.9/518.9 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.6 MB/s eta 0:00:00

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.16.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os
import json
from google.colab import data_table
import datasets
from datasets import Dataset, DatasetDict, load_dataset
import json
import re
import random
from PIL import Image

# %%
## function to check, list of columns and info from dataframe
def colInfo(dfrm):

  print(f'List of Columns: {dfrm.columns}')
  print('************************************************')
  print(f'Details info the dataframe: {dfrm.info()}')
  return None

# %%
# import pandas as pd
# df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# %%
# df1

# %%
# df1['A']

# %%
# def product(x):
#     return x['A'] * x['B']

# %%
# print(df1.apply(product, axis = 1))
# print(type(df1.apply(product, axis = 1)))

# %%
# df1['new'] = df1.apply(product, axis = 1)

# %%
# df1

# %%
# def add_squares(x,y,z):
#   # print(x,y,z)
#   x=x+10
#   y=y+10
#   z=z+10
#   return x , y , z

# %%
# # Using *df.apply() to unpack the result and pass elements as separate arguments
# df1['new1'] = add_squares(*df1.apply(product, axis = 1))

# %%
# df1

# %%
# type(df1['A'])

# %% [markdown]
# ## S-1: Basic Processing also creating full image path for Train, Valid and Test

# %%
## S-1: Custom function to create image path

def process_data(k, main_json_path, base_dir_path):

  # Open the JSON file
  with open(main_json_path, 'r') as file:
      # Load the contents of the file into a dictionary
      data = json.load(file)

  # Convert 'data' list into a dataframe
  df = pd.DataFrame(data['data'])

  df = df.iloc[:k]

  # Define a function to join the base path with the image path
  def join_paths(image_path):
      return os.path.join(base_dir_path, image_path)

  # Apply the function to create a new column with the full image path
  df['full_path_image'] = df['image'].apply(join_paths)

  def extract_ocr_info(col, ocr_base_dir):

    # Construct the ocr_path for the col
    ocr_path = os.path.join(ocr_base_dir, col['ucsf_document_id'] + '_' + col['ucsf_document_page_no'] + '.json')

    # Open the json file and load the data
    with open(ocr_path, 'r') as f:
      ocr_json = json.load(f)

    # Extract the bounding boxes and word lists from the json data
    bbox_row = []
    word_row = []
    for i in ocr_json['recognitionResults'][0]['lines']:
      for j in i['words']:
        bbox_row.append(j['boundingBox'])
        word_row.append(j['text'])

    # Return the bounding boxes and word lists
    return bbox_row, word_row

  ocr_base_dir = os.path.join(base_dir_path, sorted(os.listdir(base_dir_path))[1])

  # Apply the extract_ocr_info function to each row in the DataFrame
  df['bounding_boxes'], df['word_list'] = zip(*df.apply(lambda col: extract_ocr_info(col, ocr_base_dir), axis=1))

  df.drop(['questionId', 'image', 'ucsf_document_id', 'ucsf_document_page_no'], axis=1, inplace=True)

  return df

# %%
## Basic Processing of all three Train, Validation and Test dataset

# training usage:
train_path_main = '/content/drive/MyDrive/Datasets/docvqa_old/train/train_v1.0.json'
base_train_path = '/content/drive/MyDrive/Datasets/docvqa_old/train'

df_train_sub_ocr = process_data(20000,train_path_main, base_train_path)


# validation usage:
valid_path_main = '/content/drive/MyDrive/Datasets/docvqa_old/val/val_v1.0.json'
base_valid_path = '/content/drive/MyDrive/Datasets/docvqa_old/val'

df_valid_sub_ocr = process_data(500, valid_path_main, base_valid_path)


# test usage:
test_path_main = '/content/drive/MyDrive/docVqa_dataset/test/test_v1.0.json'
base_test_path = '/content/drive/MyDrive/docVqa_dataset/test'

df_test_sub_ocr = process_data(200, test_path_main, base_test_path)

# %%
colInfo(df_train_sub_ocr)
# Out:
# List of Columns: Index(['question', 'docId', 'answers', 'data_split', 'full_path_image',
#        'bounding_boxes', 'word_list'],
#       dtype='object')
# ************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   question         20000 non-null  object
#  1   docId            20000 non-null  int64
#  2   answers          20000 non-null  object
#  3   data_split       20000 non-null  object
#  4   full_path_image  20000 non-null  object
#  5   bounding_boxes   20000 non-null  object
#  6   word_list        20000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.1+ MB
# Details info the dataframe: None

# %%
colInfo(df_valid_sub_ocr)
# Out:
# List of Columns: Index(['question', 'docId', 'answers', 'data_split', 'full_path_image',
#        'bounding_boxes', 'word_list'],
#       dtype='object')
# ************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   question         500 non-null    object
#  1   docId            500 non-null    int64
#  2   answers          500 non-null    object
#  3   data_split       500 non-null    object
#  4   full_path_image  500 non-null    object
#  5   bounding_boxes   500 non-null    object
#  6   word_list        500 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 27.5+ KB
# Details info the dataframe: None

# %%
colInfo(df_test_sub_ocr)
# Out:
# List of Columns: Index(['question', 'docId', 'data_split', 'full_path_image', 'bounding_boxes',
#        'word_list'],
#       dtype='object')
# ************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   question         200 non-null    object
#  1   docId            200 non-null    int64
#  2   data_split       200 non-null    object
#  3   full_path_image  200 non-null    object
#  4   bounding_boxes   200 non-null    object
#  5   word_list        200 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 9.5+ KB
# Details info the dataframe: None

# %% [markdown]
# ## S-2: Convert Pandas Dataframe to Huggingface Dataset

# %%
## Convert dataframe into huggingface dataset object for all training , validation and test

# 1. Convert training dataset
hf_train_sub_ocr = Dataset.from_pandas(df_train_sub_ocr)

# 2. Convert validation dataset
hf_valid_sub_ocr = Dataset.from_pandas(df_valid_sub_ocr)

# 3. Convert test dataset
hf_test_sub_ocr = Dataset.from_pandas(df_test_sub_ocr)

# %% [markdown]
# ## S-3: Removing image path and Adding raw image on Train, Valid and Test

# %%
## S-3: Custom function to remove image path and read in Pillow & store all the images also delete the path

# Define a function to open and save images
def process_image(hfsample):
  image_path = hfsample['full_path_image']
  image = Image.open(image_path)
  hfsample['image_raw'] = image
  del hfsample['full_path_image']
  return hfsample

# %%
# Apply the function to each row in the dataset for train, valid and test

# 1. For train
hf_train_sub_ocr_imgraw = hf_train_sub_ocr.map(process_image)

# 2. For valid
hf_valid_sub_ocr_imgraw = hf_valid_sub_ocr.map(process_image)

# 3. For test
hf_test_sub_ocr_imgraw = hf_test_sub_ocr.map(process_image)
# Out:
# Map:   0%|          | 0/20000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]

# %%
hf_train_sub_ocr_imgraw
# Out:
# Dataset({
#     features: ['question', 'docId', 'answers', 'data_split', 'bounding_boxes', 'word_list', 'image_raw'],
#     num_rows: 20000
# })

# %%
# for index,i in enumerate(hf_train_sub_ocr_imgraw['question']):
#   print(index, i)
  # hf_train_json = json.loads(i)
  # print(index,hf_train_json)

# %% [markdown]
# ## S-4: Add 'ground_truth' on Training and Validation

# %%
## S-4: Custom function to add 'ground_truth' column in the training and validation dataset

# Creating custom function for DOCVQA task
def add_ground_truth(hf_examples):
  images = hf_examples['image_raw']
  questions = hf_examples['question']
  answers = hf_examples['answers']

  ground_truths = []    # Creating empty list
  for image,question, answer in zip(images,questions, answers):
    # we need to escape " characters appearing in the query and/or answer
    question = question.replace("\\", "") ## this was just one corrupt example (index 91 of training set)
    question = re.sub(' +', ' ', question)
    question = question.replace('"', '\\"')   # replacement of " from question
    # let's create the ground truth string
    ground_truth_example = '{"gt_parses": ['
    for idx, answ in enumerate(answer):
      # ans = answ.replace('"', '\"')   # replacement of " from answer
      answ = answ.replace("\\", "")
      ans = answ.replace('"', '\\"')
      ground_truth_example += '{"question" : "' + question + '", "answer" : "' + ans + '"}'

      # add comma for more than one element present in the answer list
      if idx != len(answer) - 1:   # when current index is not equal to last index
        ground_truth_example += ', '
    ground_truth_example += ']}'
    ground_truths.append(ground_truth_example)    ## appending ground_truths list for every row

  hf_examples['ground_truth'] = ground_truths

  return hf_examples

# %%
## Creating ground truth string for all three dataset train, valid and test dataset

# For Training
hf_train_sub_ocr_imgraw_gt = hf_train_sub_ocr_imgraw.map(add_ground_truth, batched=True)

# For Validation
hf_valid_sub_ocr_imgraw_gt = hf_valid_sub_ocr_imgraw.map(add_ground_truth, batched=True)

# *** Note : For Test data as there is no such answers column so we will not processed further
# hf_test_sub_ocr_imgraw = hf_test_sub_ocr_imgraw.map(add_ground_truth, batched=True)
# Out:
# Map:   0%|          | 0/20000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]

# %% [markdown]
# ### Train data sample check

# %%
hf_train_sub_ocr_imgraw_gt
# Out:
# Dataset({
#     features: ['question', 'docId', 'answers', 'data_split', 'bounding_boxes', 'word_list', 'image_raw', 'ground_truth'],
#     num_rows: 20000
# })

# %%
hf_train_sub_ocr_imgraw_gt['ground_truth'][10595]
# Out:
# '{"gt_parses": [{"question" : "What is the attachment along with this letter?", "answer" : "Women\'s HOPE study posters"}, {"question" : "What is the attachment along with this letter?", "answer" : "Womens HOPE study posters"}]}'

# %%
for index,i in enumerate(hf_train_sub_ocr_imgraw_gt['ground_truth']):
  # print(index, i)
  hf_train_json = json.loads(i)
  print(index,hf_train_json)
# Out:
# Streaming output truncated to the last 5000 lines.
# 15000 {'gt_parses': [{'question': 'Whats the TOTAL in PERSONNEL?', 'answer': '$ 7,600.00'}, {'question': 'Whats the TOTAL in PERSONNEL?', 'answer': '$7,600.00'}]}
# 15001 {'gt_parses': [{'question': 'what is the name of the college mentioned in the given letter?', 'answer': 'Imperial college of science and technology'}]}
# 15002 {'gt_parses': [{'question': 'How many months did J. A. King presumed his pre-doctor fellowship?', 'answer': '3'}]}
# 15003 {'gt_parses': [{'question': 'what is the name of the department mentioned in the given letter?', 'answer': 'DEPARTMENT OF CHEMISTRY'}, {'question': 'what is the name of the department mentioned in the given letter?', 'answer': 'department of chemistry'}]}
# 15004 {'gt_parses': [{'question': 'to whom this letter was written ?', 'answer': 'Dr. Milligan'}, {'question': 'to whom this letter was written ?', 'answer': 'Dr. W. O. Milligan'}]}
# 15005 {'gt_parses': [{'question': "what's the cost of Sampling and Film processing device?", 'answer': '$ 770.00'}, {'question': "what's the cost of Sampling and Film processing device?", 'answer': '$770.00'}]}
# 15006 {'gt_parses': [{'question': 'to which university the Imperial college of science and technology is affiliated ??', 'answer': 'UNIVERSITY OF LONDON'}, {'question': 'to which university the Imperial college of science and technology is affiliated ??', 'answer': 'university of London'}]}
# 15007 {'gt_parses': [{'question': 'Name the equipment which costs 7,500.00 dollars?', 'answer': 'Joyce-Loebl Mark III, Microdensitometer'}]}
# 15008 {'gt_parses': [{'question': 'what is the designation of Dr. W . O. Milligan ?', 'answer': 'Director of Research'}, {'question': 'what is the designation of Dr. W . O. Milligan ?', 'answer': 'Director of research'}, {'question': 'what is the designation of Dr. W . O. Milligan ?', 'answer': 'Director'}]}
# 15009 {'gt_parses': [{'question': 'what is the budget for direct mail in the year 1958 ?', 'answer': '$42,900'}, {'question': 'what is the budget for direct mail in the year 1958 ?', 'answer': '$ 42,900'}]}
# 15010 {'gt_parses': [{'question': 'How many dollars were spent in total for PERMANENT SCIENTIFIC EQUIPMENT?', 'answer': '$ 17,600.00'}, {'question': 'How many dollars were spent in total for PERMANENT SCIENTIFIC EQUIPMENT?', 'answer': '$17,600.00'}]}
# 15011 {'gt_parses': [{'question': 'what is the budget of publications in the year 1958 ?', 'answer': '6,900'}, {'question': 'what is the budget of publications in the year 1958 ?', 'answer': '-6,900'}]}
# 15012 {'gt_parses': [{'question': 'what is the budget for publications in the year 1959 ?', 'answer': '4,800'}]}
# 15013 {'gt_parses': [{'question': 'what is the budget for others in the year 1958 ?', 'answer': '900'}]}
# 15014 {'gt_parses': [{'question': 'what is the budget for others in the year 1959 ?', 'answer': '1,000'}]}
# 15015 {'gt_parses': [{'question': 'what is the amount of total budget in the year 1958 ?', 'answer': '$50,700'}, {'question': 'what is the amount of total budget in the year 1958 ?', 'answer': '$ 50,700'}]}
# 15016 {'gt_parses': [{'question': 'How many dollars were spent for Taxis?', 'answer': '2.50'}]}
# 15017 {'gt_parses': [{'question': 'what is the amount of total budget in the year 1959 ?', 'answer': '$46,200'}, {'question': 'what is the amount of total budget in the year 1959 ?', 'answer': '$ 46,200'}]}
# 15018 {'gt_parses': [{'question': 'what is the date mentioned in the given page ?', 'answer': 'February 27, 1959'}]}
# 15019 {'gt_parses': [{'question': "What's amount for P. R. R. New York to Philadelphia?", 'answer': '$6.74'}]}
# 15020 {'gt_parses': [{'question': 'by whom the appropriation was approved ?', 'answer': 'Executive Committee'}, {'question': 'by whom the appropriation was approved ?', 'answer': 'executive committee'}]}
# 15021 {'gt_parses': [{'question': 'what is the name of the laboratories mentioned in the given page ?', 'answer': 'ABBOTT LABORATORIES'}, {'question': 'what is the name of the laboratories mentioned in the given page ?', 'answer': 'Abbott laboratories'}]}
# 15022 {'gt_parses': [{'question': 'what are the expenses for R.T. Champaign to chicago on March 25?', 'answer': '$7.54'}, {'question': 'what are the expenses for R.T. Champaign to chicago on March 25?', 'answer': '$ 7.54'}]}
# 15023 {'gt_parses': [{'question': 'Where did he used 1.60 dollars?', 'answer': 'TIPS'}, {'question': 'Where did he used 1.60 dollars?', 'answer': 'Tips'}]}
# 15024 {'gt_parses': [{'question': 'what are the expenses towards taxis on march 25?', 'answer': '2.25'}]}
# 15025 {'gt_parses': [{'question': 'what are the expenses towards dinner on march 25 ?', 'answer': '3.25'}]}
# 15026 {'gt_parses': [{'question': 'what are the expenses towards hotel on march 25 ?', 'answer': '9.50'}]}
# 15027 {'gt_parses': [{'question': 'what are the expenses towards breakfast on march 26 ?', 'answer': '1.46'}]}
# 15028 {'gt_parses': [{'question': 'what is this about?', 'answer': 'telephone expenses'}, {'question': 'what is this about?', 'answer': 'Telephone Expenses'}]}
# 15029 {'gt_parses': [{'question': 'what are the expenses for R.T. Champaign to N.Chicago on March 26?', 'answer': '2.04'}]}
# 15030 {'gt_parses': [{'question': 'what are the expenses towards dinner on march 26 ?', 'answer': '4.40'}]}
# 15031 {'gt_parses': [{'question': 'What disease did sailors at sea have many years ago?', 'answer': 'SCURVY'}, {'question': 'What disease did sailors at sea have many years ago?', 'answer': 'scurvy'}]}
# 15032 {'gt_parses': [{'question': 'what are the expenses towards breakfast on march 27 ?', 'answer': '1.29'}]}
# 15033 {'gt_parses': [{'question': 'How many dollars were used in Champaign III. to Cambridge, Mass.?', 'answer': '$2.25'}]}
# 15034 {'gt_parses': [{'question': 'What is the vitamin present in lemon juice?', 'answer': 'VITAMIN C'}, {'question': 'What is the vitamin present in lemon juice?', 'answer': 'vitamin C'}]}
# 15035 {'gt_parses': [{'question': 'what is the amount of total expenses shown in the given page ?', 'answer': '$43.93'}, {'question': 'what is the amount of total expenses shown in the given page ?', 'answer': '$ 43.93'}]}
# 15036 {'gt_parses': [{'question': "What's the amount added as tax?", 'answer': '.76'}]}
# 15037 {'gt_parses': [{'question': 'Which Dutch physician experimented on the condition of people in Java?', 'answer': 'EIJKMAN'}, {'question': 'Which Dutch physician experimented on the condition of people in Java?', 'answer': 'Eijkman'}]}
# 15038 {'gt_parses': [{'question': 'Which Vitamin did Eijkman discover?', 'answer': 'B VITAMINS'}, {'question': 'Which Vitamin did Eijkman discover?', 'answer': 'B vitamins'}]}
# 15039 {'gt_parses': [{'question': 'What is the hotel expense?', 'answer': '$15.00 per day'}, {'question': 'What is the hotel expense?', 'answer': '$ 15.00 per day'}]}
# 15040 {'gt_parses': [{'question': 'When is the meeting for chemists and engineers', 'answer': 'may 26 to 29'}, {'question': 'When is the meeting for chemists and engineers', 'answer': 'May 26 to 29'}]}
# 15041 {'gt_parses': [{'question': 'what is the designation of Dr. O.E. May ?', 'answer': 'Vice President'}, {'question': 'what is the designation of Dr. O.E. May ?', 'answer': 'vice president'}]}
# 15042 {'gt_parses': [{'question': 'to whom this letter was written ?', 'answer': 'Orville'}, {'question': 'to whom this letter was written ?', 'answer': 'Dr. O. E. May'}]}
# 15043 {'gt_parses': [{'question': 'what is the name of the division mentioned in the given letter ?', 'answer': 'Technical Division'}, {'question': 'what is the name of the division mentioned in the given letter ?', 'answer': 'technical division'}, {'question': 'what is the name of the division mentioned in the given letter ?', 'answer': 'Technical'}]}
# 15044 {'gt_parses': [{'question': 'Which association is mentioned?', 'answer': 'Member Companies And Associations'}, {'question': 'Which association is mentioned?', 'answer': 'MEMBER COMPANIES AND ASSOCIATIONS'}]}
# 15045 {'gt_parses': [{'question': 'what is the P.O.Box number mentioned in the given page ?', 'answer': '1734'}]}
# 15046 {'gt_parses': [{'question': 'Which is the member company in AUSTRALIA?', 'answer': 'The Colonial Sugar Refining Company Limited'}, {'question': 'Which is the member company in AUSTRALIA?', 'answer': 'The Colonial Sugar Refining'}]}
# 15047 {'gt_parses': [{'question': 'what is the cost of round trip ticket champaign to chicago ?', 'answer': '7.37'}]}
# 15048 {'gt_parses': [{'question': 'Where is the Utah-Idaho Sugar Company located?', 'answer': 'United States Of America'}, {'question': 'Where is the Utah-Idaho Sugar Company located?', 'answer': 'UNITED STATES OF AMERICA'}]}
# 15049 {'gt_parses': [{'question': 'what is the cost of round trip ticket chicago to north chicago ?', 'answer': '2.04'}]}
# 15050 {'gt_parses': [{'question': 'Which company is from IRELAND?', 'answer': 'Irish Sugar Company Ltd.'}]}
# 15051 {'gt_parses': [{'question': 'what is the consulting fee on december 1 and 2 ?', 'answer': '400.00'}]}
# 15052 {'gt_parses': [{'question': 'what is the cost of dinner on nov. 30 ?', 'answer': '3.10'}]}
# 15053 {'gt_parses': [{'question': 'When is the letter dated?', 'answer': 'November 27, 1961'}]}
# 15054 {'gt_parses': [{'question': 'what is the cost of hotel on nov. 30 ?', 'answer': '12.00'}]}
# 15055 {'gt_parses': [{'question': 'To whom is the letter addressed?', 'answer': 'Dr. Warren J. Close'}, {'question': 'To whom is the letter addressed?', 'answer': 'Warren'}]}
# 15056 {'gt_parses': [{'question': 'what is the total expenses on nov. 30 ?', 'answer': '16.35'}]}
# 15057 {'gt_parses': [{'question': 'Who is the sender?', 'answer': 'Roger Adams'}]}
# 15058 {'gt_parses': [{'question': 'what is the total expenses on dec. 1 ?', 'answer': '1.60'}]}
# 15059 {'gt_parses': [{'question': 'what is the cost of taxi on dec. 2 ?', 'answer': '.60'}]}
# 15060 {'gt_parses': [{'question': 'What food does Group I contain?', 'answer': 'Milk'}]}
# 15061 {'gt_parses': [{'question': 'what is the cost of dinner on dec. 2?', 'answer': '2.50'}]}
# 15062 {'gt_parses': [{'question': 'what is the total expenses on dec. 2 ?', 'answer': '4.35'}]}
# 15063 {'gt_parses': [{'question': 'How many pints of milk should rapidly growing boys and girls have each day?', 'answer': '1 to 2 pints'}]}
# 15064 {'gt_parses': [{'question': 'what is the name mentioned in the given report ?', 'answer': 'Roger Adams'}]}
# 15065 {'gt_parses': [{'question': 'How many ounces does a serving equal?', 'answer': 'about 3 ounces'}, {'question': 'How many ounces does a serving equal?', 'answer': 'about 3 ounces.'}]}
# 15066 {'gt_parses': [{'question': 'what is the date mentioned in the given report ?', 'answer': '11/12/1962'}]}
# 15067 {'gt_parses': [{'question': 'How much charged for Repair to equipment?', 'answer': '$200'}]}
# 15068 {'gt_parses': [{'question': 'How many servings of vegetables and fruits are recommended per day?', 'answer': '4 or more servings'}, {'question': 'How many servings of vegetables and fruits are recommended per day?', 'answer': '4 or more servings per day'}]}
# 15069 {'gt_parses': [{'question': 'what is the name of the department mentioned in the given report ?', 'answer': 'CENTRAL RESEARCH DEPARTMENT'}, {'question': 'what is the name of the department mentioned in the given report ?', 'answer': 'central research department'}]}
# 15070 {'gt_parses': [{'question': 'where was 40 dollars charged for?', 'answer': 'books'}, {'question': 'where was 40 dollars charged for?', 'answer': 'Books'}]}
# 15071 {'gt_parses': [{'question': 'Which hotel is mentioned?', 'answer': 'HOTEL DU PONT'}]}
# 15072 {'gt_parses': [{'question': 'What is the number written at the top right of the page?', 'answer': '20822'}]}
# 15073 {'gt_parses': [{'question': 'What is the balance due on JAN-5-59?', 'answer': '21.00'}, {'question': 'What is the balance due on JAN-5-59?', 'answer': '*   21.00'}]}
# 15074 {'gt_parses': [{'question': 'What is the document title?', 'answer': 'DENTAL RECORD'}]}
# 15075 {'gt_parses': [{'question': 'what is the date mentioned in the given telegram ?', 'answer': '1961 DEC 29'}]}
# 15076 {'gt_parses': [{'question': 'When do the incisors come for permanent teeth?', 'answer': '7 TO 9 YEARS'}]}
# 15077 {'gt_parses': [{'question': 'what is the name of the union ?', 'answer': 'WESTERN UNION'}, {'question': 'what is the name of the union ?', 'answer': 'western union'}]}
# 15078 {'gt_parses': [{'question': 'What are the Reprints and Publication Charges of scientific articles arising from grant?', 'answer': '$675'}]}
# 15079 {'gt_parses': [{'question': 'who is the president of western union ?', 'answer': 'W.P. MARSHALL'}, {'question': 'who is the president of western union ?', 'answer': 'W.P. Marshall'}]}
# 15080 {'gt_parses': [{'question': 'What is another name for 3RD MOLAR?', 'answer': 'WISDOM TOOTH'}]}
# 15081 {'gt_parses': [{'question': 'what does DL stands for ?', 'answer': 'Day Letter'}, {'question': 'what does DL stands for ?', 'answer': 'day letter'}]}
# 15082 {'gt_parses': [{'question': 'what does NL stands for ?', 'answer': 'Night Letter'}, {'question': 'what does NL stands for ?', 'answer': 'night letter'}]}
# 15083 {'gt_parses': [{'question': 'Which foundation is mentioned at the top of the page?', 'answer': 'THE ROBERT A. WELCH FOUNDATION'}]}
# 15084 {'gt_parses': [{'question': 'who has passed away this morning as mentioned in the telegram ?', 'answer': 'MR ANDREWS'}, {'question': 'who has passed away this morning as mentioned in the telegram ?', 'answer': 'MR Andrews'}]}
# 15085 {'gt_parses': [{'question': 'From whom is the document?', 'answer': 'Dr. Joe E. Hodgkins, TCU'}]}
# 15086 {'gt_parses': [{'question': 'What is the grant No.?', 'answer': 'P-058'}]}
# 15087 {'gt_parses': [{'question': 'When is the letter dated?', 'answer': 'March 4, 1963'}]}
# 15088 {'gt_parses': [{'question': 'what is the name of the report ?', 'answer': 'TRAVELING EXPENSE REPORT'}, {'question': 'what is the name of the report ?', 'answer': 'traveling expense report'}]}
# 15089 {'gt_parses': [{'question': 'When was the letter received?', 'answer': 'March 9, 1963'}]}
# 15090 {'gt_parses': [{'question': 'what is the name of the department mentioned in the given report ?', 'answer': 'CENTRAL RESEARCH DEPARTMENT'}, {'question': 'what is the name of the department mentioned in the given report ?', 'answer': 'central research department'}]}
# 15091 {'gt_parses': [{'question': 'What is the subject of the letter?', 'answer': 'Requests supplementary Grant in accordance with ABR: $16,000'}, {'question': 'What is the subject of the letter?', 'answer': 'Requests supplementary Grant in accordance with ABR; $16,000'}]}
# 15092 {'gt_parses': [{'question': 'what is the date mentioned in the given report ?', 'answer': 'Dec. 15, 1961'}, {'question': 'what is the date mentioned in the given report ?', 'answer': 'Dec. 15 , 1961'}]}
# 15093 {'gt_parses': [{'question': 'In which hotel is the meeting going to be held?', 'answer': 'jung hotel'}, {'question': 'In which hotel is the meeting going to be held?', 'answer': 'JUNG HOTEL'}]}
# 15094 {'gt_parses': [{'question': 'Who is the speaker on March 21?', 'answer': 'mr. e. j. forio'}, {'question': 'Who is the speaker on March 21?', 'answer': 'Mr. E. J. Forio'}]}
# 15095 {'gt_parses': [{'question': "What is E. J. Forio's designation?", 'answer': 'senior vice president'}, {'question': "What is E. J. Forio's designation?", 'answer': 'Senior Vice President'}]}
# 15096 {'gt_parses': [{'question': 'Which company is Forio the Senior Vice President of?', 'answer': 'the coca-cola company'}, {'question': 'Which company is Forio the Senior Vice President of?', 'answer': 'The Coca-Cola Company'}]}
# 15097 {'gt_parses': [{'question': 'Who will give the Introductory Remarks on March 22?', 'answer': 'charles H. Brokaw'}, {'question': 'Who will give the Introductory Remarks on March 22?', 'answer': 'Charles H. Brokaw'}]}
# 15098 {'gt_parses': [{'question': "What is J. Spencer Brewer's topic from 2:40 - 3:15?", 'answer': 'automatic drum filling'}, {'question': "What is J. Spencer Brewer's topic from 2:40 - 3:15?", 'answer': 'Automatic Drum Filling'}]}
# 15099 {'gt_parses': [{'question': 'what is the cost of gas chromatographic equipment ?', 'answer': '$1000'}, {'question': 'what is the cost of gas chromatographic equipment ?', 'answer': '$ 1000'}]}
# 15100 {'gt_parses': [{'question': 'what is the cost of chemicals ?', 'answer': '$650'}, {'question': 'what is the cost of chemicals ?', 'answer': '$ 650'}]}
# 15101 {'gt_parses': [{'question': 'what is the cost for laboratory hardware and glassware ?', 'answer': '$500'}, {'question': 'what is the cost for laboratory hardware and glassware ?', 'answer': '$ 500'}]}
# 15102 {'gt_parses': [{'question': 'what is the cost of shop work ?', 'answer': '$230'}, {'question': 'what is the cost of shop work ?', 'answer': '$ 230'}]}
# 15103 {'gt_parses': [{'question': 'Who was the Director of The Great Western Sugar Company?', 'answer': 'mr. whitney newton II'}, {'question': 'Who was the Director of The Great Western Sugar Company?', 'answer': 'Mr. Whitney Newton II'}]}
# 15104 {'gt_parses': [{'question': 'what is the total cost of expandable scientific items and services ?', 'answer': '$1730'}, {'question': 'what is the total cost of expandable scientific items and services ?', 'answer': '$ 1,730'}]}
# 15105 {'gt_parses': [{'question': 'what is the cost of reprints of scientific articles arising from grant ?', 'answer': '$102'}, {'question': 'what is the cost of reprints of scientific articles arising from grant ?', 'answer': '$ 102'}]}
# 15106 {'gt_parses': [{'question': 'what is the value of total expenses mentioned in the given page ?', 'answer': '$20,000'}, {'question': 'what is the value of total expenses mentioned in the given page ?', 'answer': '$ 20,000'}]}
# 15107 {'gt_parses': [{'question': 'what is the date mentioned in the given page ?', 'answer': 'september 21, 1960'}, {'question': 'what is the date mentioned in the given page ?', 'answer': 'September 21 , 1960'}]}
# 15108 {'gt_parses': [{'question': 'what are the expenses for champaign to new orleans and return as mentioned in the given letter ?', 'answer': '84.35'}, {'question': 'what are the expenses for champaign to new orleans and return as mentioned in the given letter ?', 'answer': '$ 84.35'}]}
# 15109 {'gt_parses': [{'question': 'what is the cost of taxis ?', 'answer': '4.50'}]}
# 15110 {'gt_parses': [{'question': 'what is the cost of hotel,on march 21,22,23 ?', 'answer': '30.90'}]}
# 15111 {'gt_parses': [{'question': 'what are the expenses for tips mentioned in the given page ?', 'answer': '3.35'}]}
# 15112 {'gt_parses': [{'question': 'what is the cost of meals ?', 'answer': '30.83'}]}
# 15113 {'gt_parses': [{'question': 'what are the total expenses mentioned in the given page ?', 'answer': '$ 153.93'}]}
# 15114 {'gt_parses': [{'question': 'what are the expenses for R.T. Champaign to chicago ?', 'answer': '$9.98'}, {'question': 'what are the expenses for R.T. Champaign to chicago ?', 'answer': '$ 9.98'}, {'question': 'what are the expenses for R.T. Champaign to chicago ?', 'answer': '$9 98'}]}
# 15115 {'gt_parses': [{'question': 'what are the expenses for taxi on february 17 ?', 'answer': '2.25'}, {'question': 'what are the expenses for taxi on february 17 ?', 'answer': '2 25'}]}
# 15116 {'gt_parses': [{'question': 'what are the expenses for dinner on february 17 ?', 'answer': '3.75'}, {'question': 'what are the expenses for dinner on february 17 ?', 'answer': '3 75'}]}
# 15117 {'gt_parses': [{'question': 'what are the expenses for hotel on February 17 ?', 'answer': '11.50'}, {'question': 'what are the expenses for hotel on February 17 ?', 'answer': '11 50'}]}
# 15118 {'gt_parses': [{'question': 'what are the expenses for breakfast on February 18 ?', 'answer': '1.35'}, {'question': 'what are the expenses for breakfast on February 18 ?', 'answer': '1 35'}]}
# 15119 {'gt_parses': [{'question': 'what are the expenses for dinner on February 18 ?', 'answer': '4.25'}, {'question': 'what are the expenses for dinner on February 18 ?', 'answer': '4 25'}]}
# 15120 {'gt_parses': [{'question': 'what is the cost of hotel on february 18 ?', 'answer': '11.50'}, {'question': 'what is the cost of hotel on february 18 ?', 'answer': '11 50'}]}
# 15121 {'gt_parses': [{'question': 'what is the cost of taxi on February 18 ?', 'answer': '1.20'}, {'question': 'what is the cost of taxi on February 18 ?', 'answer': '1 20'}]}
# 15122 {'gt_parses': [{'question': 'what is the cost for one way chicago to north chicago on February 19 ?', 'answer': '1.02'}, {'question': 'what is the cost for one way chicago to north chicago on February 19 ?', 'answer': '1 02'}]}
# 15123 {'gt_parses': [{'question': 'what are the total expenses mentioned in the given page ?', 'answer': '$59.99'}, {'question': 'what are the total expenses mentioned in the given page ?', 'answer': '$ 59.99'}, {'question': 'what are the total expenses mentioned in the given page ?', 'answer': '$59 99'}]}
# 15124 {'gt_parses': [{'question': 'what is the cost for champaign to philadelphis on january 4 ?', 'answer': '$59.73'}, {'question': 'what is the cost for champaign to philadelphis on january 4 ?', 'answer': '$ 59.73'}]}
# 15125 {'gt_parses': [{'question': 'what is the cost for meals on january 4 ?', 'answer': '7.35'}]}
# 15126 {'gt_parses': [{'question': 'what is the cost of hotel on january 4 ?', 'answer': '10.50'}]}
# 15127 {'gt_parses': [{'question': 'what is the cost of taxi on january 5 ?', 'answer': '1.75'}]}
# 15128 {'gt_parses': [{'question': 'what is the cost of breakfast on january 5 ?', 'answer': '1.70'}]}
# 15129 {'gt_parses': [{'question': 'what is the cost of hotel on january 5 ?', 'answer': '10.50'}]}
# 15130 {'gt_parses': [{'question': 'what is the cost of taxis on january 6 ?', 'answer': '3.50'}]}
# 15131 {'gt_parses': [{'question': 'what is the cost of meals on january 6 ?', 'answer': '6.10'}]}
# 15132 {'gt_parses': [{'question': 'what are the total expenses mentioned in the given page ?', 'answer': '$106.88'}, {'question': 'what are the total expenses mentioned in the given page ?', 'answer': '$ 106.88'}]}
# 15133 {'gt_parses': [{'question': 'what is the cost of tips on january 6 ?', 'answer': '.50'}]}
# 15134 {'gt_parses': [{'question': 'on which date the dinner is scheduled ?', 'answer': 'JANUARY 22, 1960'}, {'question': 'on which date the dinner is scheduled ?', 'answer': 'January 22, 1960'}]}
# 15135 {'gt_parses': [{'question': 'what is the designation of Dr. Emil M. Mrak ?', 'answer': 'CHANCELLOR'}, {'question': 'what is the designation of Dr. Emil M. Mrak ?', 'answer': 'chancellor'}]}
# 15136 {'gt_parses': [{'question': 'what is the designation of Dr. Byron T. Shaw ?', 'answer': 'RESEARCH ADMINISTRATOR'}, {'question': 'what is the designation of Dr. Byron T. Shaw ?', 'answer': 'research administrator'}]}
# 15137 {'gt_parses': [{'question': 'Who is the President?', 'answer': 'DR. PHILIP ROSS'}, {'question': 'Who is the President?', 'answer': 'Dr. Philip Ross'}]}
# 15138 {'gt_parses': [{'question': 'Who is the Vice President and Director of Research?', 'answer': 'DR. JOHN L. HICKSON'}, {'question': 'Who is the Vice President and Director of Research?', 'answer': 'Dr. John L. Hickson'}]}
# 15139 {'gt_parses': [{'question': 'Which is the Department?', 'answer': 'department of biology'}, {'question': 'Which is the Department?', 'answer': 'Department of Biology'}]}
# 15140 {'gt_parses': [{'question': 'What is the Title of Proposed Research?', 'answer': 'iron supplementation of milk'}, {'question': 'What is the Title of Proposed Research?', 'answer': 'Iron Supplementation of Milk'}]}
# 15141 {'gt_parses': [{'question': 'When is the Desired Starting Date?', 'answer': 'on approval of contract'}, {'question': 'When is the Desired Starting Date?', 'answer': 'On approval of contract'}]}
# 15142 {'gt_parses': [{'question': 'What is the Time Period?', 'answer': '1 year'}]}
# 15143 {'gt_parses': [{'question': 'What is the Amount Requested?', 'answer': '$4,026'}]}
# 15144 {'gt_parses': [{'question': 'What is Total Direct Costs?', 'answer': '$3000'}]}
# 15145 {'gt_parses': [{'question': 'What is the Title of the document?', 'answer': 'BUDGET REQUEST'}, {'question': 'What is the Title of the document?', 'answer': 'Budget Request'}]}
# 15146 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'MAY 1, 1967 THROUGH APRIL 30, 1968'}, {'question': 'What is the date on the document?', 'answer': 'May 1, 1967 through April 30, 1968'}]}
# 15147 {'gt_parses': [{'question': 'Who is the Principal Investigator?', 'answer': 'JOHN J. BANEWICZ'}, {'question': 'Who is the Principal Investigator?', 'answer': 'John J. Banewicz'}]}
# 15148 {'gt_parses': [{'question': 'What is the Summer stipend for John J. Banewicz?', 'answer': '$4100'}]}
# 15149 {'gt_parses': [{'question': 'What is the cost for Liquid Nitrogen?', 'answer': '$200'}]}
# 15150 {'gt_parses': [{'question': 'What is the cost for Chemicals and Supplies?', 'answer': '$435'}]}
# 15151 {'gt_parses': [{'question': 'What is the Date?', 'answer': 'DECEMBER 11, 1958'}, {'question': 'What is the Date?', 'answer': 'December 11, 1958'}]}
# 15152 {'gt_parses': [{'question': 'Who is this letter from?', 'answer': '(MRS.) I. EDMINSTER'}, {'question': 'Who is this letter from?', 'answer': '(Mrs.) I. Edminster'}]}
# 15153 {'gt_parses': [{'question': 'Whose expense account of recent trip to Chicago is enclosed?', 'answer': 'DR. ADAMS'}, {'question': 'Whose expense account of recent trip to Chicago is enclosed?', 'answer': 'Dr. Adams'}]}
# 15154 {'gt_parses': [{'question': 'The Nutritional material in this booklet was prepared under whose direction?', 'answer': 'Orville E. May'}]}
# 15155 {'gt_parses': [{'question': 'Which company does he work for?', 'answer': 'The Coca-Cola Company'}]}
# 15156 {'gt_parses': [{'question': 'What is the Cost of Round Trip Champaign to Chicago?', 'answer': '$10.16'}, {'question': 'What is the Cost of Round Trip Champaign to Chicago?', 'answer': '$10 16'}]}
# 15157 {'gt_parses': [{'question': 'What is the Cost of Feb. 28 Dinner?', 'answer': '3.40'}, {'question': 'What is the Cost of Feb. 28 Dinner?', 'answer': '3 40'}]}
# 15158 {'gt_parses': [{'question': 'What is the Cost of Round Trip Chicago to North Chicago?', 'answer': '2.04'}, {'question': 'What is the Cost of Round Trip Chicago to North Chicago?', 'answer': '2 04'}]}
# 15159 {'gt_parses': [{'question': 'What is the Title of the document?', 'answer': 'ABBOTT LABORATORIES'}, {'question': 'What is the Title of the document?', 'answer': 'Abbott Laboratories'}]}
# 15160 {'gt_parses': [{'question': 'What is the Title of the Document?', 'answer': 'TOGETHER IN ISRF RESEARCH EFFORT'}, {'question': 'What is the Title of the Document?', 'answer': 'Together in ISRF Research Effort'}]}
# 15161 {'gt_parses': [{'question': 'Who is the Managing Director of Finnish Sugar corporation?', 'answer': 'Dr. Reino Rossi'}]}
# 15162 {'gt_parses': [{'question': 'Mr. Gustav von Hertzen has been with corporation since when?', 'answer': '1954'}]}
# 15163 {'gt_parses': [{'question': 'Where is Wistar Institute of Anatomy and Biology located?', 'answer': 'Philadelphia'}]}
# 15164 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'MAY 30-31 1968'}, {'question': 'What is the date on the document?', 'answer': 'May 30-31 1968'}]}
# 15165 {'gt_parses': [{'question': 'What is the Title of the document?', 'answer': 'travel guidelines for panel members'}, {'question': 'What is the Title of the document?', 'answer': 'Travel Guidelines for panel Members'}]}
# 15166 {'gt_parses': [{'question': 'What is the allowance when travelling is accomplished by private auto?', 'answer': 'nine cents per mile'}, {'question': 'What is the allowance when travelling is accomplished by private auto?', 'answer': 'nine cents'}]}
# 15167 {'gt_parses': [{'question': 'Who will notify the members of time, date and location of meetings?', 'answer': 'panel chairmen'}, {'question': 'Who will notify the members of time, date and location of meetings?', 'answer': 'Panel Chairmen'}]}
# 15168 {'gt_parses': [{'question': 'How will the reimbursement for travel be made on?', 'answer': 'standard government travel voucher'}, {'question': 'How will the reimbursement for travel be made on?', 'answer': 'Standard Government Travel Voucher'}, {'question': 'How will the reimbursement for travel be made on?', 'answer': 'on standard government travel voucher'}]}
# 15169 {'gt_parses': [{'question': 'When was the appointment of a full time program supervisor done?', 'answer': 'APRIL 1960'}, {'question': 'When was the appointment of a full time program supervisor done?', 'answer': 'April 1960'}]}
# 15170 {'gt_parses': [{'question': 'When will a general announcement of the predoctoral ad postdoctoral traineeship be made?', 'answer': 'AUGUST 1960'}, {'question': 'When will a general announcement of the predoctoral ad postdoctoral traineeship be made?', 'answer': 'August 1960'}]}
# 15171 {'gt_parses': [{'question': 'Who is the Outside Representative?', 'answer': 'SALTMAN, PAUL D.'}, {'question': 'Who is the Outside Representative?', 'answer': 'Saltman, Paul D.'}, {'question': 'Who is the Outside Representative?', 'answer': 'SALTMAN'}]}
# 15172 {'gt_parses': [{'question': 'What is the Telephone?', 'answer': '(714) 452-3130'}]}
# 15173 {'gt_parses': [{'question': 'What is the Publication Number?', 'answer': '0 542 912 B1'}]}
# 15174 {'gt_parses': [{'question': 'What is the Title of the Document?', 'answer': 'EUROPEAN PATENT SPECIFICATION'}, {'question': 'What is the Title of the Document?', 'answer': 'European Patent Specification'}]}
# 15175 {'gt_parses': [{'question': 'What is the Date of publication of Patent specification?', 'answer': '31.05.95'}]}
# 15176 {'gt_parses': [{'question': 'What is the Application Number?', 'answer': '91916529.0'}]}
# 15177 {'gt_parses': [{'question': 'When is the Date of Filing?', 'answer': '02.08.91'}]}
# 15178 {'gt_parses': [{'question': 'What is the International Application Number?', 'answer': 'PCT/US91/05496'}]}
# 15179 {'gt_parses': [{'question': 'What is the Publication of Grant of the patent?', 'answer': '31.05.95 Bulletin 95/22'}]}
# 15180 {'gt_parses': [{'question': 'Who is the Inventor?', 'answer': 'SALTMAN, Paul, David'}, {'question': 'Who is the Inventor?', 'answer': 'Saltman, Paul, David'}]}
# 15181 {'gt_parses': [{'question': 'What is the Title of the Document?', 'answer': 'UCSD FULLY EXECUTED AWARD'}]}
# 15182 {'gt_parses': [{'question': 'What is the Date?', 'answer': '5/23/78'}]}
# 15183 {'gt_parses': [{'question': 'What is the Title of the Document?', 'answer': 'BUDGET REQUEST SUMMARY'}, {'question': 'What is the Title of the Document?', 'answer': 'Budget Request Summary'}]}
# 15184 {'gt_parses': [{'question': 'What is the Budget for Personnel for May 1, 1966 through Apr. 30, 1967?', 'answer': '$7300'}]}
# 15185 {'gt_parses': [{'question': 'What is the Budget for Permanent Scientific Equipment for May 1, 1966 through Apr. 30, 1967?', 'answer': '$2200'}]}
# 15186 {'gt_parses': [{'question': 'What is the Budget for Expendable Scientific Items and Services for May 1, 1966 through Apr. 30, 1967?', 'answer': '$685'}]}
# 15187 {'gt_parses': [{'question': 'What is the Budget for Other Expenses for May 1, 1966 through Apr. 30, 1967?', 'answer': '$250'}]}
# 15188 {'gt_parses': [{'question': 'What is the Budget for Total Exclusive of Overhead for May 1, 1966 through Apr. 30, 1967?', 'answer': '$10435'}, {'question': 'What is the Budget for Total Exclusive of Overhead for May 1, 1966 through Apr. 30, 1967?', 'answer': '$10,435'}]}
# 15189 {'gt_parses': [{'question': 'What is the Budget for Overhead for May 1, 1966 through Apr. 30, 1967?', 'answer': '$1565'}]}
# 15190 {'gt_parses': [{'question': 'What is the Total amount of Proposed Budget for May 1, 1966 through Apr. 30, 1967?', 'answer': '$12000'}, {'question': 'What is the Total amount of Proposed Budget for May 1, 1966 through Apr. 30, 1967?', 'answer': '$12,000'}]}
# 15191 {'gt_parses': [{'question': 'What is the Name of Principal Investigator?', 'answer': 'John J. Banewicz'}]}
# 15192 {'gt_parses': [{'question': 'What is the Name?', 'answer': 'Dr. Roger Adams'}, {'question': 'What is the Name?', 'answer': 'Dr. Roger adams'}]}
# 15193 {'gt_parses': [{'question': 'What is the Date?', 'answer': 'June 18, 1962'}]}
# 15194 {'gt_parses': [{'question': 'What is the Title of the Document?', 'answer': 'TRAVELING EXPENSE REPORT'}, {'question': 'What is the Title of the Document?', 'answer': 'Traveling Expense Report'}]}
# 15195 {'gt_parses': [{'question': 'What is the Date?', 'answer': 'february 4, 1966'}, {'question': 'What is the Date?', 'answer': 'February 4, 1966'}]}
# 15196 {'gt_parses': [{'question': 'Who is the Investigator?', 'answer': 'dr. john e. kilpatrick'}, {'question': 'Who is the Investigator?', 'answer': 'Dr. John E. Kilpatrick'}]}
# 15197 {'gt_parses': [{'question': 'What is the Institution?', 'answer': 'william marsh rice university'}, {'question': 'What is the Institution?', 'answer': 'William Marsh rice University'}]}
# 15198 {'gt_parses': [{'question': 'What is the Period?', 'answer': 'one year'}, {'question': 'What is the Period?', 'answer': 'One Year'}]}
# 15199 {'gt_parses': [{'question': 'What is the Title of the Document?', 'answer': 'proposal submitted for study'}, {'question': 'What is the Title of the Document?', 'answer': 'Proposal Submitted for study'}]}
# 15200 {'gt_parses': [{'question': 'What is the Date on the document?', 'answer': 'MAY 19-25, 1963'}, {'question': 'What is the Date on the document?', 'answer': 'May 19-25 1963'}]}
# 15201 {'gt_parses': [{'question': 'When is the document dated?', 'answer': 'SEPTEMBER 20, 1962'}, {'question': 'When is the document dated?', 'answer': 'September 20, 1962'}]}
# 15202 {'gt_parses': [{'question': 'Who is the Vice President and Director of Research?', 'answer': 'JOHN L. HICKSON'}]}
# 15203 {'gt_parses': [{'question': 'When is the meeting going to be held?', 'answer': 'NOVEMBER 9TH'}, {'question': 'When is the meeting going to be held?', 'answer': 'November 9th'}]}
# 15204 {'gt_parses': [{'question': 'What type of documentation is this?', 'answer': 'TRAVEL VOUCHER'}]}
# 15205 {'gt_parses': [{'question': 'When is the document dated?', 'answer': 'MAY 31, 1963'}, {'question': 'When is the document dated?', 'answer': 'May 31, 1963'}]}
# 15206 {'gt_parses': [{'question': 'Which institution is mentioned?', 'answer': 'ANDERSON HOSPITAL & TUMOR INSTITUTE'}, {'question': 'Which institution is mentioned?', 'answer': 'Anderson Hospital & Tumor Institute'}]}
# 15207 {'gt_parses': [{'question': 'When is the symposium going to be held?', 'answer': 'APRIL 12-19, 1964'}]}
# 15208 {'gt_parses': [{'question': 'What is the amount for food, taxis, incidentals at same from March 31- April 9?', 'answer': '78.79'}]}
# 15209 {'gt_parses': [{'question': 'What is the total amount at the end?', 'answer': '$446.69'}]}
# 15210 {'gt_parses': [{'question': 'What is the document about?', 'answer': 'TRAVELING EXPENSE REPORT'}]}
# 15211 {'gt_parses': [{'question': 'What is the date given?', 'answer': 'DECEMBER 15 1959'}, {'question': 'What is the date given?', 'answer': 'December 15 1959'}]}
# 15212 {'gt_parses': [{'question': 'What is the total amount?', 'answer': '63 70'}]}
# 15213 {'gt_parses': [{'question': 'What is the TOTAL, exclusive of overhead?', 'answer': '$10435'}, {'question': 'What is the TOTAL, exclusive of overhead?', 'answer': '$ 10435'}]}
# 15214 {'gt_parses': [{'question': 'Who is the President or Chancellor?', 'answer': 'WILLIS M. TATE'}, {'question': 'Who is the President or Chancellor?', 'answer': 'Willis M. Tate'}]}
# 15215 {'gt_parses': [{'question': 'When is the document dated?', 'answer': 'FEBRUARY 24, 1966'}, {'question': 'When is the document dated?', 'answer': 'February 24, 1966'}]}
# 15216 {'gt_parses': [{'question': 'Which institution is mentioned?', 'answer': 'SOUTHERN METHODIST UNIVERSITY'}, {'question': 'Which institution is mentioned?', 'answer': 'Southern Methodist University'}]}
# 15217 {'gt_parses': [{'question': 'What can be used as detergents and emulsifiers?', 'answer': 'sugar ester surfactants'}]}
# 15218 {'gt_parses': [{'question': 'The treatment of beet molasses with what improves its nutritional value for farm animals?', 'answer': 'ammonia'}]}
# 15219 {'gt_parses': [{'question': 'What is a suitable feed for cattle after hammer-milling?', 'answer': 'bagasse'}, {'question': 'What is a suitable feed for cattle after hammer-milling?', 'answer': 'Bagasse'}]}
# 15220 {'gt_parses': [{'question': 'Which institute is mentioned at the top of the page?', 'answer': 'battelle memorial institute'}, {'question': 'Which institute is mentioned at the top of the page?', 'answer': 'BATTELLE MEMORIAL INSTITUTE'}]}
# 15221 {'gt_parses': [{'question': 'What is the meeting about?', 'answer': 'trustees meeting'}, {'question': 'What is the meeting about?', 'answer': 'Trustees Meeting'}]}
# 15222 {'gt_parses': [{'question': 'When is the meeting going to be held?', 'answer': 'dec. 8, 1961'}, {'question': 'When is the meeting going to be held?', 'answer': 'Dec. 8, 1961'}]}
# 15223 {'gt_parses': [{'question': 'What is the hotel fare in dollars?', 'answer': '10.30'}]}
# 15224 {'gt_parses': [{'question': 'What is the total expense?', 'answer': '$55.02'}]}
# 15225 {'gt_parses': [{'question': 'What type of documentation is this?', 'answer': 'TRAVELING EXPENSE REPORT'}]}
# 15226 {'gt_parses': [{'question': 'Which department is involved?', 'answer': 'CHEMICAL DEPARTMENT'}]}
# 15227 {'gt_parses': [{'question': "Which company's name is mentioned?", 'answer': 'E. I. DU PONT DE NEMOURS & COMPANY'}]}
# 15228 {'gt_parses': [{'question': 'What is the document title?', 'answer': 'expenses'}, {'question': 'What is the document title?', 'answer': 'EXPENSES'}]}
# 15229 {'gt_parses': [{'question': 'Which laboratory is mentioned?', 'answer': 'abbott laboratories'}, {'question': 'Which laboratory is mentioned?', 'answer': 'ABBOTT LABORATORIES'}]}
# 15230 {'gt_parses': [{'question': 'When is the Consulting?', 'answer': 'May 21, 22, 1959'}]}
# 15231 {'gt_parses': [{'question': 'Which foundation is mentioned?', 'answer': 'the robert A. welch foundation'}, {'question': 'Which foundation is mentioned?', 'answer': 'THE ROBERT A. WELCH FOUNDATION'}]}
# 15232 {'gt_parses': [{'question': 'What is the grant No.?', 'answer': 'g-035'}, {'question': 'What is the grant No.?', 'answer': 'G-035'}]}
# 15233 {'gt_parses': [{'question': 'What is the amount of Bobelei Malick (Univ. of Texas) for undergraduate scholarships?', 'answer': '$1,000'}, {'question': 'What is the amount of Bobelei Malick (Univ. of Texas) for undergraduate scholarships?', 'answer': '$ 1,000.'}]}
# 15234 {'gt_parses': [{'question': 'Which laboratory is mentioned?', 'answer': 'ABBOTT LABORATORIES'}]}
# 15235 {'gt_parses': [{'question': 'What are the dates mentioned?', 'answer': 'May 4, 5, 6, 1960'}]}
# 15236 {'gt_parses': [{'question': 'What is the total amount?', 'answer': '$41.19'}]}
# 15237 {'gt_parses': [{'question': 'Who is the sender?', 'answer': 'edgar b carter'}, {'question': 'Who is the sender?', 'answer': 'EDGAR B CARTER'}]}
# 15238 {'gt_parses': [{'question': 'When is the program?', 'answer': 'december sixth'}, {'question': 'When is the program?', 'answer': 'DECEMBER SIXTH'}]}
# 15239 {'gt_parses': [{'question': 'When is the document dated?', 'answer': 'december 6 1968'}, {'question': 'When is the document dated?', 'answer': 'DECEMBER 6 1968'}]}
# 15240 {'gt_parses': [{'question': 'Which institution is mentioned?', 'answer': 'TEXAS CHRISTIAN UNIVERSITY'}, {'question': 'Which institution is mentioned?', 'answer': 'Texas Christian University'}]}
# 15241 {'gt_parses': [{'question': 'When is the document dated?', 'answer': 'MARCH 4, 1963'}, {'question': 'When is the document dated?', 'answer': 'March 4, 1963'}]}
# 15242 {'gt_parses': [{'question': 'What is the document title?', 'answer': 'expenses'}, {'question': 'What is the document title?', 'answer': 'EXPENSES'}]}
# 15243 {'gt_parses': [{'question': 'When is the document dated?', 'answer': 'april 17, 1959'}, {'question': 'When is the document dated?', 'answer': 'April 17, 1959'}]}
# 15244 {'gt_parses': [{'question': 'What is the expense of round trip Champaign to Columbus?', 'answer': '$71.06'}]}
# 15245 {'gt_parses': [{'question': 'What is the total amount in $?', 'answer': '89.65'}]}
# 15246 {'gt_parses': [{'question': 'Who is the investigator?', 'answer': 'John E. Kilpatrick'}, {'question': 'Who is the investigator?', 'answer': 'John E Kilpatrick'}]}
# 15247 {'gt_parses': [{'question': 'What is the title?', 'answer': 'Low Temperature Calorimetry and Statistical Mechanics'}, {'question': 'What is the title?', 'answer': 'Low temperature calorimetry and statistical Mechanics'}]}
# 15248 {'gt_parses': [{'question': 'What is lunch time?', 'answer': '12:30 - 1:45'}, {'question': 'What is lunch time?', 'answer': '12.30 - 1.45'}]}
# 15249 {'gt_parses': [{'question': 'What is date mentioned', 'answer': 'tuesday, march 23'}, {'question': 'What is date mentioned', 'answer': 'Tuesday, March 23'}]}
# 15250 {'gt_parses': [{'question': 'What meeting is mentioned?', 'answer': "branch chemists' meeting"}, {'question': 'What meeting is mentioned?', 'answer': 'Branch Chemists Meeting'}]}
# 15251 {'gt_parses': [{'question': 'What is the period?', 'answer': 'MAY 1, 1966 THROUGH APRIL 30, 1967'}, {'question': 'What is the period?', 'answer': 'May 1, 1966, through April 30 1967'}]}
# 15252 {'gt_parses': [{'question': 'What amount is going to pay to John J. Banewicz for three months?', 'answer': '$4000'}, {'question': 'What amount is going to pay to John J. Banewicz for three months?', 'answer': '4000'}]}
# 15253 {'gt_parses': [{'question': 'What amount is budgeted for pre doctoral fellowship?', 'answer': '$3300'}, {'question': 'What amount is budgeted for pre doctoral fellowship?', 'answer': '3300'}]}
# 15254 {'gt_parses': [{'question': 'What is cost of liquid Nitrogen?', 'answer': '$200'}, {'question': 'What is cost of liquid Nitrogen?', 'answer': '200'}]}
# 15255 {'gt_parses': [{'question': 'What is the date of the document?', 'answer': 'april 8, 1959'}, {'question': 'What is the date of the document?', 'answer': 'April 8, 1959'}]}
# 15256 {'gt_parses': [{'question': 'What is cost of dinner?', 'answer': '7.75'}]}
# 15257 {'gt_parses': [{'question': 'What is tips amount?', 'answer': '.50'}]}
# 15258 {'gt_parses': [{'question': 'What is R.T Champaign to Chicago', 'answer': '$12.55'}, {'question': 'What is R.T Champaign to Chicago', 'answer': '$ 12.55'}]}
# 15259 {'gt_parses': [{'question': 'Who is sender?', 'answer': 'thomas a. craig'}, {'question': 'Who is sender?', 'answer': 'Thomas A. Craig'}]}
# 15260 {'gt_parses': [{'question': 'Date of the memorandum?', 'answer': 'march 12'}, {'question': 'Date of the memorandum?', 'answer': 'March 12'}]}
# 15261 {'gt_parses': [{'question': 'Where is the place "Urbanas" ?', 'answer': 'illinois'}, {'question': 'Where is the place "Urbanas" ?', 'answer': 'Illinois'}]}
# 15262 {'gt_parses': [{'question': 'Time of seminar on crown testing?', 'answer': '8:00 p.m.'}, {'question': 'Time of seminar on crown testing?', 'answer': '8.00 p.m'}]}
# 15263 {'gt_parses': [{'question': 'Who speaks " Plant design in Canada"', 'answer': 'l. hunter'}, {'question': 'Who speaks " Plant design in Canada"', 'answer': 'L. Hunter'}]}
# 15264 {'gt_parses': [{'question': 'What is the date mentioned?', 'answer': 'OCT 11 1973'}, {'question': 'What is the date mentioned?', 'answer': 'Oct 11, 1973'}]}
# 15265 {'gt_parses': [{'question': 'What is designation of Joesph F. Glencoe', 'answer': 'ASSISTANT PROFESSOR OF BIOLOGY'}, {'question': 'What is designation of Joesph F. Glencoe', 'answer': 'Assistant professor of Biology'}]}
# 15266 {'gt_parses': [{'question': 'Who is the member mentioned in this document?', 'answer': 'DERSE, PHILIP H.'}]}
# 15267 {'gt_parses': [{'question': 'What is senders name?', 'answer': 'paul saltman'}, {'question': 'What is senders name?', 'answer': 'Paul Saltman'}]}
# 15268 {'gt_parses': [{'question': 'Who is the receiver of the letter?', 'answer': 'eva herbst'}, {'question': 'Who is the receiver of the letter?', 'answer': 'EVA HERBST'}]}
# 15269 {'gt_parses': [{'question': 'Which city DERSE, PHILIP H. belongs to?', 'answer': 'Madison, Wisconsin'}, {'question': 'Which city DERSE, PHILIP H. belongs to?', 'answer': 'Madison'}]}
# 15270 {'gt_parses': [{'question': 'What is the Telephone No mentioned in this document?', 'answer': '(608) 241-4471'}]}
# 15271 {'gt_parses': [{'question': 'What amount is Fee?', 'answer': '$10,000'}, {'question': 'What amount is Fee?', 'answer': '$ 10,000'}, {'question': 'What amount is Fee?', 'answer': '10,000'}]}
# 15272 {'gt_parses': [{'question': 'What is the Reference given in this document?', 'answer': 'American Men of Science, 11th Edition, 1960'}]}
# 15273 {'gt_parses': [{'question': 'To whom the CC is sent?', 'answer': 'Paul Saltman'}]}
# 15274 {'gt_parses': [{'question': 'Who wrote this letter?', 'answer': 'Jack Hegenauer'}]}
# 15275 {'gt_parses': [{'question': 'What is the amount of Zinc Chloride present in mineral calcium-fortified chewable lozenges as given in Example V?', 'answer': '31.3 mg'}, {'question': 'What is the amount of Zinc Chloride present in mineral calcium-fortified chewable lozenges as given in Example V?', 'answer': '31.3'}]}
# 15276 {'gt_parses': [{'question': 'Which ingredient with the amount of 12.5mg is present in mineral calcium-fortified chewable lozenges as given in Example V?', 'answer': 'Manganese Gluconate'}]}
# 15277 {'gt_parses': [{'question': 'Which ingredient with the amount of 2500mg is present in mineral calcium-fortified chewable lozenges as given in Example V?', 'answer': 'Calcium citrate-malate (6:2:3)'}, {'question': 'Which ingredient with the amount of 2500mg is present in mineral calcium-fortified chewable lozenges as given in Example V?', 'answer': 'Calcium  citrate-malate (6:2:3)'}, {'question': 'Which ingredient with the amount of 2500mg is present in mineral calcium-fortified chewable lozenges as given in Example V?', 'answer': 'Calcium citrate-malate'}]}
# 15278 {'gt_parses': [{'question': 'What is the amount (percent) of Granular Sucrose in a chocolate powder mix as given in Example VI?', 'answer': '66.88'}]}
# 15279 {'gt_parses': [{'question': 'What is the amount (percent) of Non-fat Dry milk present in a chocolate powder mix as given in Example VI?', 'answer': '15.00'}]}
# 15280 {'gt_parses': [{'question': 'Which university is mentioned in the header of the document?', 'answer': 'UNIVERSITY OF CALIFORNIA. SAN DIEGO'}, {'question': 'Which university is mentioned in the header of the document?', 'answer': 'UNIVERSITY OF CALIFORNIA, SAN DIEGO'}]}
# 15281 {'gt_parses': [{'question': 'What is the designation of Jack Hegenauer?', 'answer': 'Associate Research Biologist'}]}
# 15282 {'gt_parses': [{'question': 'Who is the Vice-Chancellor for Academic Aaffairs, University of California, San Diego?', 'answer': 'Paul Saltman'}]}
# 15283 {'gt_parses': [{'question': 'What is the Contact no of Paul Saltman mentioned in the document?', 'answer': '(714) 452-3130'}]}
# 15284 {'gt_parses': [{'question': 'What is the title of Proposed Research given in the document?', 'answer': 'IRON AND COPPER FORTIFICATION OF MILK'}]}
# 15285 {'gt_parses': [{'question': 'What is the time-period mentioned in the document?', 'answer': '1 August 1976 - 31 March 1977'}]}
# 15286 {'gt_parses': [{'question': 'What is the Amount Requested as per the document?', 'answer': '$ 4999'}, {'question': 'What is the Amount Requested as per the document?', 'answer': '4999'}]}
# 15287 {'gt_parses': [{'question': 'what is the title of the document ?', 'answer': 'MEDICAL BIOPHYSICS'}, {'question': 'what is the title of the document ?', 'answer': 'Medical Biophysics'}]}
# 15288 {'gt_parses': [{'question': 'who is the person mentioned as dear in the letter ?', 'answer': 'PAUL'}, {'question': 'who is the person mentioned as dear in the letter ?', 'answer': 'paul'}]}
# 15289 {'gt_parses': [{'question': "Which organization's name is in the letter head?", 'answer': 'National Dairy Council'}, {'question': "Which organization's name is in the letter head?", 'answer': 'NATIONAL DAIRY COUNCIL'}]}
# 15290 {'gt_parses': [{'question': 'What is the received date of this letter?', 'answer': 'MAY 15 1980'}]}
# ...
# 19875 {'gt_parses': [{'question': 'How many reviews were received?', 'answer': 'one'}]}
# 19876 {'gt_parses': [{'question': 'How many words of copy?', 'answer': '1170'}]}
# 19877 {'gt_parses': [{'question': 'What amount was the check for?', 'answer': '$29.25'}, {'question': 'What amount was the check for?', 'answer': '29.25'}]}
# 19878 {'gt_parses': [{'question': 'What is the Stipend?', 'answer': 'from $855 to $900'}, {'question': 'What is the Stipend?', 'answer': 'From $855 to $900'}, {'question': 'What is the Stipend?', 'answer': '$855 to $900'}]}
# 19879 {'gt_parses': [{'question': 'Applications must be submitted by when?', 'answer': 'january 29, 1963'}, {'question': 'Applications must be submitted by when?', 'answer': 'January 29, 1963'}]}
# 19880 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'July 9, 1953'}]}
# 19881 {'gt_parses': [{'question': 'To Whom is this letter addressed to?', 'answer': 'Dr. Robert E. Shank'}]}
# 19882 {'gt_parses': [{'question': 'Who is this letter from?', 'answer': 'H. Callender'}, {'question': 'Who is this letter from?', 'answer': 'Assistant Treasurer'}]}
# 19883 {'gt_parses': [{'question': 'What is the Fee for the month of June 1953?', 'answer': '$22.85'}, {'question': 'What is the Fee for the month of June 1953?', 'answer': '22.85'}]}
# 19884 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': '4-1-79'}]}
# 19885 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'thursday, april 26th'}, {'question': 'What is the date on the document?', 'answer': 'Thursday, April 26th'}]}
# 19886 {'gt_parses': [{'question': 'When is the Morning session?', 'answer': '9:00 a.m.'}, {'question': 'When is the Morning session?', 'answer': '9:00 A.M.'}]}
# 19887 {'gt_parses': [{'question': 'What is the Date?', 'answer': 'january 1, 1976'}, {'question': 'What is the Date?', 'answer': 'January 1, 1976'}]}
# 19888 {'gt_parses': [{'question': 'What is the Name?', 'answer': 'schenck, jeanne'}, {'question': 'What is the Name?', 'answer': 'Schenck, Jeanne'}]}
# 19889 {'gt_parses': [{'question': 'When was he born?', 'answer': 'november 1, 1925'}, {'question': 'When was he born?', 'answer': 'November 1, 1925'}]}
# 19890 {'gt_parses': [{'question': 'What is the marital status?', 'answer': 'single'}, {'question': 'What is the marital status?', 'answer': 'Single'}]}
# 19891 {'gt_parses': [{'question': 'What is the Home Phone?', 'answer': '744-5106'}]}
# 19892 {'gt_parses': [{'question': 'What is the Home Address?', 'answer': '7205 poplar, galveston, texas, 77550'}, {'question': 'What is the Home Address?', 'answer': '7205 Poplar, Galveston, Texas, 77550'}]}
# 19893 {'gt_parses': [{'question': 'When was it mailed?', 'answer': '6/11/70'}]}
# 19894 {'gt_parses': [{'question': 'What is the Name?', 'answer': 'Dr. Robert E. Shank'}]}
# 19895 {'gt_parses': [{'question': 'What is the Birth date?', 'answer': 'Sept. 2, 1914'}]}
# 19896 {'gt_parses': [{'question': 'What is the Birth place?', 'answer': 'Louisville, Ky.'}]}
# 19897 {'gt_parses': [{'question': 'What is the Title of the document?', 'answer': 'Industrial Advisory Committee'}]}
# 19898 {'gt_parses': [{'question': 'Who is the Chairman?', 'answer': 'E. W. Reid'}]}
# 19899 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'june 2, 1955'}, {'question': 'What is the date on the document?', 'answer': 'June 2, 1955'}]}
# 19900 {'gt_parses': [{'question': 'Who is it published by?', 'answer': 'THE NUTRITION FOUNDATION, INC.'}, {'question': 'Who is it published by?', 'answer': 'The Nutrition Foundation Inc.'}]}
# 19901 {'gt_parses': [{'question': 'To Whom is this letter addressed to?', 'answer': 'Dr. Shank'}]}
# 19902 {'gt_parses': [{'question': 'How many reviews have been received?', 'answer': 'two'}]}
# 19903 {'gt_parses': [{'question': 'For which month have been the reviews for?', 'answer': 'may'}, {'question': 'For which month have been the reviews for?', 'answer': 'May'}]}
# 19904 {'gt_parses': [{'question': 'How many words of copy?', 'answer': '2350'}]}
# 19905 {'gt_parses': [{'question': 'What is the amount of check?', 'answer': '$58.75'}]}
# 19906 {'gt_parses': [{'question': 'Who is this letter from?', 'answer': 'CHRISTINE S. WILSON'}, {'question': 'Who is this letter from?', 'answer': 'Christine S. Wilson'}]}
# 19907 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'February 12, 1975'}]}
# 19908 {'gt_parses': [{'question': 'To Whom is this letter addressed to?', 'answer': 'Dr. Robert Shank'}, {'question': 'To Whom is this letter addressed to?', 'answer': 'Bob'}]}
# 19909 {'gt_parses': [{'question': 'Who is this letter from?', 'answer': 'William H. Daughaday, M.D.'}, {'question': 'Who is this letter from?', 'answer': 'William H. Daughaday'}]}
# 19910 {'gt_parses': [{'question': 'What are the Total pounds food issued?', 'answer': '49,049,558'}]}
# 19911 {'gt_parses': [{'question': 'What are Retail value food issued?', 'answer': '$20,743,059'}]}
# 19912 {'gt_parses': [{'question': 'What is the total cars shipped into state?', 'answer': '959'}]}
# 19913 {'gt_parses': [{'question': 'what is the retail value of shipments received?', 'answer': '$23,380,968'}]}
# 19914 {'gt_parses': [{'question': 'What is the average monthly persons receiving?', 'answer': '234,509'}]}
# 19915 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'August 23rd, 1971'}]}
# 19916 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'October 11, 1971'}]}
# 19917 {'gt_parses': [{'question': 'Who is this letter from?', 'answer': 'Dr. Philip R. Dodge'}, {'question': 'Who is this letter from?', 'answer': 'Dr. Philip R. Dodge, Chairman - Committee to Consider'}]}
# 19918 {'gt_parses': [{'question': 'What is the DHEW Publication No.?', 'answer': 'hsm 72-6502'}, {'question': 'What is the DHEW Publication No.?', 'answer': 'HSM 72-6502'}]}
# 19919 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'October 25, 1961'}]}
# 19920 {'gt_parses': [{'question': 'To Whom is this letter addressed to?', 'answer': 'Mr. J. C. Claywell'}, {'question': 'To Whom is this letter addressed to?', 'answer': 'Mr. Claywell'}]}
# 19921 {'gt_parses': [{'question': 'What is the Total Charges for Hospital Charges?', 'answer': '$355'}]}
# 19922 {'gt_parses': [{'question': "What is the Total Charges for Physicians' Visits in hospital?", 'answer': '92'}]}
# 19923 {'gt_parses': [{'question': 'What is the Total Charges for private registered nurses in hospital?', 'answer': '355'}]}
# 19924 {'gt_parses': [{'question': "What is the Total Charges for Examinations at Doctor's office?", 'answer': '195'}]}
# 19925 {'gt_parses': [{'question': "What is the Total Charges for Physician's visits at home?", 'answer': '290'}]}
# 19926 {'gt_parses': [{'question': 'What is the Total Charges for Private registered nurses at home?', 'answer': '315'}]}
# 19927 {'gt_parses': [{'question': 'What is the Total Charges for Prescription Medicinea at home?', 'answer': '110'}]}
# 19928 {'gt_parses': [{'question': 'What is the amount paid by TIAA?', 'answer': '964'}, {'question': 'What is the amount paid by TIAA?', 'answer': '$964'}]}
# 19929 {'gt_parses': [{'question': 'What is the amount paid by Blue cross-Blue Shield?', 'answer': '$407'}]}
# 19930 {'gt_parses': [{'question': 'What is the amount paid by staff member?', 'answer': '341'}]}
# 19931 {'gt_parses': [{'question': 'What is the Company or foundation?', 'answer': 'pet milk, Inc'}, {'question': 'What is the Company or foundation?', 'answer': 'Pet Milk, Inc'}]}
# 19932 {'gt_parses': [{'question': 'What is the Address?', 'answer': '400 south 4th street'}, {'question': 'What is the Address?', 'answer': '400 South 4th street'}]}
# 19933 {'gt_parses': [{'question': 'What is the City?', 'answer': 'st louis'}, {'question': 'What is the City?', 'answer': 'St. Louis'}]}
# 19934 {'gt_parses': [{'question': 'What is the Actual date and time of appointment?', 'answer': '1:30 p.m. friday april 25, 1969'}, {'question': 'What is the Actual date and time of appointment?', 'answer': '1:30 p.m. Friday April 25, 1969'}]}
# 19935 {'gt_parses': [{'question': 'Who made the appt?', 'answer': 'sue segrest'}, {'question': 'Who made the appt?', 'answer': 'Sue Segrest'}]}
# 19936 {'gt_parses': [{'question': 'What is the House Document No.?', 'answer': '227'}]}
# 19937 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'june 1955'}, {'question': 'What is the date on the document?', 'answer': 'June 1955'}]}
# 19938 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'November 7, 1961'}]}
# 19939 {'gt_parses': [{'question': 'What is the department?', 'answer': 'Wohl Clinic'}]}
# 19940 {'gt_parses': [{'question': 'What is the suggested source?', 'answer': 'Holscher-Wernig'}]}
# 19941 {'gt_parses': [{'question': 'What is the cost estimate for Health Policy Ins. Core Support for 1988?', 'answer': '40,000'}]}
# 19942 {'gt_parses': [{'question': 'What is the cost estimate for Health Issues forum for 1988?', 'answer': '25,000'}]}
# 19943 {'gt_parses': [{'question': 'What is the cost estimate for Nursing Recruitment/Training for 1988?', 'answer': '100,000'}]}
# 19944 {'gt_parses': [{'question': 'What is the cost estimate for Biomedical Development Corp. for 1988?', 'answer': '100,000'}]}
# 19945 {'gt_parses': [{'question': 'What is the cost estimate for Public Health case Studies/Training for 1988?', 'answer': '75,000'}]}
# 19946 {'gt_parses': [{'question': 'What is the cost estimate for Health Policy Ins. Core Support for 1989?', 'answer': '60,000'}]}
# 19947 {'gt_parses': [{'question': 'What is the cost estimate for Health Issues forum for 1989?', 'answer': '35,000'}]}
# 19948 {'gt_parses': [{'question': 'What is the cost estimate for Nursing Recruitment/Training for 1989?', 'answer': '200,000'}]}
# 19949 {'gt_parses': [{'question': 'What is the cost estimate for Biomedical Development Corp. for 1989?', 'answer': '100,000'}]}
# 19950 {'gt_parses': [{'question': 'What is the cost estimate for Public Health case Studies/Training for 1989?', 'answer': '150,000'}]}
# 19951 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': '10/3/75'}]}
# 19952 {'gt_parses': [{'question': 'When is the Registration on Wednesday, October 15, 1975?', 'answer': '8:00 a.m.'}]}
# 19953 {'gt_parses': [{'question': 'Where is the Registration on Wednesday, October 15, 1975?', 'answer': 'Viking Hall'}]}
# 19954 {'gt_parses': [{'question': 'When is the Registration on Thursday, October 16, 1975?', 'answer': '7:45 a.m.'}]}
# 19955 {'gt_parses': [{'question': 'When is the Welcome and Introduction on Wednesday, October 15, 1975?', 'answer': '8:45 a.m.'}]}
# 19956 {'gt_parses': [{'question': 'When is the Welcome and Introduction on Thursday, October 16, 1975?', 'answer': '8:15 a.m.'}]}
# 19957 {'gt_parses': [{'question': 'Who is presiding the morning session on Wednesday, October 15, 1975?', 'answer': 'Dr. Marshall McLeod'}]}
# 19958 {'gt_parses': [{'question': 'Who is presiding the morning session on Thursday, October 16, 1975?', 'answer': 'Mr. Frank Parrino'}]}
# 19959 {'gt_parses': [{'question': 'Who is presiding the afternoon session on Thursday, October 16, 1975?', 'answer': 'Ms. Muriel Caldwell'}]}
# 19960 {'gt_parses': [{'question': 'Who is presiding the afternoon session on Wednesday, October 15, 1975?', 'answer': 'Mr. William Snyder'}]}
# 19961 {'gt_parses': [{'question': 'When is the summary comments on Thursday, October 16, 1975?', 'answer': '3:45 p.m.'}]}
# 19962 {'gt_parses': [{'question': 'When is the document dated?', 'answer': 'August 16, 1955'}]}
# 19963 {'gt_parses': [{'question': 'From which place is the document sent?', 'answer': 'Chicago, Illinois'}]}
# 19964 {'gt_parses': [{'question': 'Who is the sender?', 'answer': 'Paul Perles'}]}
# 19965 {'gt_parses': [{'question': 'Who is A History of the Southern Medical Association by?', 'answer': 'C. P. Loranz'}]}
# 19966 {'gt_parses': [{'question': 'Which committee is mentioned?', 'answer': 'FOOD INDUSTRIES ADVISORY COMMITTEE'}]}
# 19967 {'gt_parses': [{'question': 'Where is the program going to be held?', 'answer': 'Skytop, Pennsylvania'}]}
# 19968 {'gt_parses': [{'question': 'At what time is the Morning Session?', 'answer': '9:30 A.M.'}]}
# 19969 {'gt_parses': [{'question': 'Who is talking about the review of the Nutrition Foundation program?', 'answer': 'C. G. King'}]}
# 19970 {'gt_parses': [{'question': "What is Norvin C. Kiefer's topic?", 'answer': 'Health Services and special weapons in civil defense'}]}
# 19971 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'December 7, 1976'}]}
# 19972 {'gt_parses': [{'question': 'What is the Total?', 'answer': '107.02'}, {'question': 'What is the Total?', 'answer': '107 02'}]}
# 19973 {'gt_parses': [{'question': 'How much is Consulting Travel and Per Diem?', 'answer': '7,500.00'}]}
# 19974 {'gt_parses': [{'question': 'What is the subtotal?', 'answer': '$135,692.00'}]}
# 19975 {'gt_parses': [{'question': 'How much is administration (11%)?', 'answer': '14,926.00'}]}
# 19976 {'gt_parses': [{'question': 'What is the Total?', 'answer': '$150,618.00'}]}
# 19977 {'gt_parses': [{'question': 'Who is it signed by?', 'answer': 'C. O. Chichester, Ph.D.'}, {'question': 'Who is it signed by?', 'answer': 'C. O. Chichester'}]}
# 19978 {'gt_parses': [{'question': 'What is the Title of the document?', 'answer': 'Historical Perspectives in Nutrition'}, {'question': 'What is the Title of the document?', 'answer': 'Historical perspectives in nutrition'}]}
# 19979 {'gt_parses': [{'question': 'Who is the president?', 'answer': 'William J. Darby, M.D., Ph.D.'}, {'question': 'Who is the president?', 'answer': 'William J. Darby'}]}
# 19980 {'gt_parses': [{'question': 'What is the Title of the document?', 'answer': 'Out-of-Pocket Expenses'}]}
# 19981 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'October 6-8, 1979'}]}
# 19982 {'gt_parses': [{'question': 'What is the amount for Taxi: LaGuardia to Union League Club, Oct. 8?', 'answer': '$9.50'}]}
# 19983 {'gt_parses': [{'question': 'What is the amount for Gratuities?', 'answer': '2.00'}]}
# 19984 {'gt_parses': [{'question': 'When is the Board Receipt/Dinner?', 'answer': 'Monday, December 8, 1986'}]}
# 19985 {'gt_parses': [{'question': 'Where is Jere E. Goyan from?', 'answer': 'University of California'}, {'question': 'Where is Jere E. Goyan from?', 'answer': 'University Of California'}]}
# 19986 {'gt_parses': [{'question': 'What is the Cardmember Acct No.?', 'answer': '3728 078330 22005'}]}
# 19987 {'gt_parses': [{'question': 'Who is Donald K. Tressler?', 'answer': 'Scientific Director of the Institute'}]}
# 19988 {'gt_parses': [{'question': 'Who is the publisher?', 'answer': 'Andrew Alan Hyman'}]}
# 19989 {'gt_parses': [{'question': 'What is the date on the document?', 'answer': 'August 15, 1955'}]}
# 19990 {'gt_parses': [{'question': 'To Whom is this letter addressed to?', 'answer': 'Dr. Shank'}]}
# 19991 {'gt_parses': [{'question': 'Who is this letter from?', 'answer': 'Paul Perles'}]}
# 19992 {'gt_parses': [{'question': 'Where did he pass two weeks ago?', 'answer': 'Camp Miniwauca'}]}
# 19993 {'gt_parses': [{'question': 'What is the Total?', 'answer': '477.00'}]}
# 19994 {'gt_parses': [{'question': 'What is the Ticket Number?', 'answer': '001 4467049276 4'}]}
# 19995 {'gt_parses': [{'question': 'What is the Date of Issue?', 'answer': '12 Oct'}, {'question': 'What is the Date of Issue?', 'answer': '12 OCT'}]}
# 19996 {'gt_parses': [{'question': 'What is the Form of Payment?', 'answer': 'TP1016-33245-000191-AC'}]}
# 19997 {'gt_parses': [{'question': 'Who is Neal Ball?', 'answer': 'vice president'}, {'question': 'Who is Neal Ball?', 'answer': 'Vice President'}, {'question': 'Who is Neal Ball?', 'answer': 'Vice president american hospital Supply Corporation'}]}
# 19998 {'gt_parses': [{'question': 'When is the document dated?', 'answer': 'March 7, 1975'}]}
# 19999 {'gt_parses': [{'question': 'To whom is the letter addressed?', 'answer': 'Mr. William L. Farrelly'}, {'question': 'To whom is the letter addressed?', 'answer': 'Mr. Farrelly'}]}

# %% [markdown]
# ### Valid data sample check

# %%
hf_valid_sub_ocr_imgraw_gt
# Out:
# Dataset({
#     features: ['question', 'docId', 'answers', 'data_split', 'bounding_boxes', 'word_list', 'image_raw', 'ground_truth'],
#     num_rows: 500
# })

# %%
# for index,i in enumerate(hf_valid_sub_ocr_imgraw_gt['ground_truth']):
#   # print(index, i)
#   hf_valid_json = json.loads(i)
#   print(index,hf_valid_json)

# %% [markdown]
# ### Test data sample check

# %%
hf_test_sub_ocr_imgraw
# Out:
# Dataset({
#     features: ['question', 'docId', 'data_split', 'bounding_boxes', 'word_list', 'image_raw'],
#     num_rows: 200
# })

# %% [markdown]
# ## S-5.1: Huggingface dataset to csv transform and download

# %%
## Download train csv format
# hf_train_sub_ocr_imgraw_gt.to_csv("/content/drive/MyDrive/DOCVQA_Processed_Dataset/docvqa_sub_2600_wo_fuzz/docvqa_sub_train_2000.csv")

# %%
## Download valid csv format
# hf_valid_sub_ocr_imgraw_gt.to_csv("/content/drive/MyDrive/DOCVQA_Processed_Dataset/docvqa_sub_2600_wo_fuzz/docvqa_sub_valid_400.csv")

# %%
## Download test csv format
# hf_test_sub_ocr_imgraw.to_csv("/content/drive/MyDrive/DOCVQA_Processed_Dataset/docvqa_sub_2600_wo_fuzz/docvqa_sub_test_200.csv")

# %% [markdown]
# ## S-5.2: Huggingface dataset to json transform and download

# %%
## Download train json format
# hf_train_sub_ocr_imgraw_gt.to_json("/content/drive/MyDrive/DOCVQA_Processed_Dataset/docvqa_sub_2600_wo_fuzz/docvqa_sub_train_2000.json")

## Download valid json format
# hf_valid_sub_ocr_imgraw_gt.to_json("/content/drive/MyDrive/DOCVQA_Processed_Dataset/docvqa_sub_2600_wo_fuzz/docvqa_sub_valid_400.json")

## Download test json format
# hf_test_sub_ocr_imgraw.to_json("/content/drive/MyDrive/DOCVQA_Processed_Dataset/docvqa_sub_2600_wo_fuzz/docvqa_sub_test_200.json")

# %% [markdown]
# #### Note: Problem when using save_from_disk and Push to hub
# - We can save to and load from disk for DatasetDict if different features in training, validation and test dataset have.
# - But if different features (columns) will present then we can't push the DatasetDict to hub

# %%
# from datasets import load_from_disk

# %% [markdown]
# ## S-6: Upload and Reload sub Dataset in HuggingFace Hub both with gt_prompt and without gt_prompt

# %%
# With gt_prompt

## To push the DatsetDict into hub we must have same features for all dataset

# for train and validation
processed_sub_train_valid_20500_gtparse = DatasetDict(
    {"train": hf_train_sub_ocr_imgraw_gt,
     "valid": hf_valid_sub_ocr_imgraw_gt,
})

# Without gt_prompt
## To push the DatsetDict into hub we must have same features for all dataset
# for train and validation
processed_sub_train_valid_20500 = DatasetDict(
    {"train": hf_train_sub_ocr_imgraw,
     "valid": hf_valid_sub_ocr_imgraw,
})

# for test data no separate datasets are required
processed_sub_test_200 = DatasetDict(
    {"test": hf_test_sub_ocr_imgraw
})

# %%
# !huggingface-cli login      # indra-inc
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# with gt_prompt train and valid
processed_sub_train_valid_20500_gtparse.push_to_hub("indra-inc/docvqa_en_train_valid_20500_gtparse")

# without gt_prompt train and valid
processed_sub_train_valid_20500.push_to_hub("indra-inc/docvqa_en_train_valid_20500")

# test data
processed_sub_test_200.push_to_hub("indra-inc/docvqa_en_test_200")
# Out:
# Map:   0%|          | 0/2858 [00:00<?, ? examples/s]
# Pushing dataset shards to the dataset hub:   0%|          | 0/7 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/2857 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/2857 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/2857 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/2857 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/2857 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/2857 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Deleting unused files from dataset repository:   0%|          | 0/5 [00:00<?, ?it/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading metadata:   0%|          | 0.00/860 [00:00<?, ?B/s]
# Map:   0%|          | 0/2858 [00:00<?, ? examples/s]
# Pushing dataset shards to the dataset hub:   0%|          | 0/7 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/2857 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/2857 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/2857 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/2857 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/2857 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/2857 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/29 [00:00<?, ?ba/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading metadata:   0%|          | 0.00/659 [00:00<?, ?B/s]

# %%
## Reload the train and valid dataset dict
# processed_trn_vld_loaded_sub_20500_gtparse = load_dataset('indra-inc/docvqa_en_train_valid_20500_gtparse')
# processed_trn_vld_loaded_sub_20500 = load_dataset('indra-inc/docvqa_en_train_valid_20500')

## Reload the test dataset dict
# processed_tst_loaded_sub_200 = load_dataset('indra-inc/docvqa_en_test_200')

# %%
## Checking whether reloading done successfully or not
# processed_trn_vld_loaded_sub_20500_gtparse

# %%
# processed_trn_vld_loaded_sub_20500

# %%
# processed_tst_loaded_sub_200

# %% [markdown]
# ## End Note:
# We did all these steps successfully and our subset dataset uploaded successfully.
